# %% [markdown]
# # Create path plots

# %%
from simba.plotting.path_plotter_mp import PathPlotterMulticore

# %%
#DEFINITIONS

## MY SIMBA CONFIG FILE
CONFIG_PATH = '/Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/project_config.ini'

#MY PLOT ATTRIBUTES (OPTIONAL) If None, then autocomputed - max lines will be set to 2s.
PLOT_ATTRIBUTES = {'width': 'As input', 
                   'height': 'As input', 
                   'line width': 5, 
                   'font size': 5, 
                   'font thickness': 2, 
                   'circle size': 5, 
                   'bg color': 'White', 
                   'max lines': 2000}

#ANIMAL LINE ATTRIBUTES - DEFINES THE BODY PARTS TO USE WHEN CREATING PATH PLOTS AND THEIR COLORS
ANIMAL_ATTRIBUTES = {0: ['Ear_right_1', 'Red'], 1: ['Ear_right_2', 'Green']}


#CLASSIFICATION ATTRIBUTES - DEFINES HOW TO MARK THE LOCATION OF CLASSIFIED BEVAHIORS, THEIR CIRCLE SIZE, AND CIRCLE COLORS
# If None then no behavior classification location will be shown.
CLASSIFICATION_ATTRIBUTES = {0: ['Attack', 'Black', 'Size: 30']}

#NOTE: VALID COLOR NAMES: 
# Grey, Red, Dark-red, Maroon, Orange, Dark-orange, Coral, Chocolate, Yellow, Green, Dark-grey, Light-grey, Pink, Lime
# Purple, Cyan, White, Black, Darkgoldenrod, Olive, Seagreen, Dodgerblue, Springgreen, Firebrick, Indigo

# %%
# RUN THE PLOTTER
path_plotter = PathPlotterMulticore(config_path=CONFIG_PATH,
                                    frame_setting=False, #If True, creates individual .png images
                                    video_setting=True, #If True, creates mp4 video
                                    last_frame=True, #If True, .png of the last frame will be created.
                                    input_clf_attr=CLASSIFICATION_ATTRIBUTES,
                                    input_style_attr=PLOT_ATTRIBUTES,
                                    animal_attr=ANIMAL_ATTRIBUTES,
                                    files_found=['/Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/csv/machine_results/Together_1.csv'],
                                    cores=5)
path_plotter.run()
# Out:
# Processing 1 videos...
# SIMBA COMPLETE: Final path plot saved at /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/frames/output/path_plots/Together_1_final_frame.png (elapsed time: 0.0832s) 	complete
# Creating path plots, multiprocessing (chunksize: 1, cores: 5)...
# Image 348/1738, Video 1/1...
# Image 696/1738, Video 1/1...
# Image 1044/1738, Video 1/1...
# Image 1392/1738, Video 1/1...
# Image 1740/1738, Video 1/1...
# Joining Together_1 multiprocessed video...
# SIMBA COMPLETE: Video concatenated (elapsed time: 25.0461s) 	complete
# Path plot video Together_1 complete (elapsed time: 94.8699s) ...
# SIMBA COMPLETE: Path plot visualizations for 1 videos created in project_folder/frames/output/path_plots directory (elapsed time: 94.9046s) 	complete
