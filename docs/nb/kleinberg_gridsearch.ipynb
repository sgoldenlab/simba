# %% [markdown]
# ### This notebook iterates over a batch of Kleinberg hyperparameters in a set of input files containing behavior classifications. The results of each iteration is saved in a separate output directory. Before running the code, make sure you have simba-uw-tf-dev > 1.82.5 installed.

# %%
import os.path
from itertools import product
from simba.data_processors.kleinberg_calculator import KleinbergCalculator

# %% [markdown]
# SPECIFY KLEINBERG PARAMETERS.
# All the different 4-way combinations of values will be run. For example, the below values will results in
# 72 different combinations of Kleinberg smoothings, saved in 72 different output folders.
# You may want to remove some values, if you have a lot of data, and want to spare disk space.
# For information on the parameters see the [SimBA GitHub Repo](https://github.com/sgoldenlab/simba/blob/master/docs/kleinberg_filter.md).

# %%
SIGMAS = [1.5, 2.0, 3.0]
GAMMAS = [0.1, 0.2, 0.3, 0.5]
HIERARCHIES = [1, 2, 3]
HIERARCHY_SEARCH = [True, False]

# %% [markdown]
# SPECIFY CLASSIFIERS AND PATHS

# %%
#NAMES OF THE BEHAVIORS IN YOUR SIMBA PROJECT YOU WANT TO PERFORM KLEINBERG SMOOTHING ON
CLASSIFIER_NAMES = ['Attack', 'Sniffing', 'Rear']
#THE FULL PATH TO YOUR SIMBA PROJECT CONFIG FILE
PROJECT_CONFIG_PATH = r'/Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/project_config.ini'
#THE DIRECTORY HOLDING THE DATA FILES WITH BEHAVIOR COLUMNS THAT YOU WANT TO SMOOTH
INPUT_DIR = r'/Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/csv/machine_results'
#THE OUTPUT DIRECTORY WHERE THE SMOOTHENED DATA SHOULD BE STORED. ONE SUB-DIRECTORY INSIDE THIS OUTPUT DIRECTORY WILL BE CREATED PER PARAMETER COMBINATION
OUTPUT_DIR = r'/Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/csv/kleinberg_gridsearch_test'

# %% [markdown]
# RUN THE KLEINBERG ANALYSIS. ONCE COMPLETE, THE RESULTS CAN BE FOUND IN THE SPECIFIED OUTPUT_DIR ABOVE.
# THE RESULTS WILL BE SAVED IN SUB-DIRECTORIES THAT INDICATE THE SPECIFIC PARAMETERS USED.
# FOR EXAMPLE, A DIRECTORY CALLED s3.0_g0.2_h3_hsTrue INSIDE THE OUTPUT_DIR TRANSLATE TO sigma = 3.0, gamma = 0.2, hierarchy = 3, hierarchy search = TRUE.

# %%
for cnt, param in enumerate(list(product(SIGMAS, GAMMAS, HIERARCHIES, HIERARCHY_SEARCH))):
    s, g, h, hs = param
    print(f'Running parameters ({cnt+1}/{len(list(product(SIGMAS, GAMMAS, HIERARCHIES, HIERARCHY_SEARCH)))}): sigma = {s}, gamma = {g}, hierarchy = {h}, hierarchy search = {hs}')
    save_dir = os.path.join(OUTPUT_DIR, f's{s}_g{g}_h{h}_hs{hs}')
    if not os.path.isdir(save_dir): os.makedirs(save_dir)
    kleinberg_runner = KleinbergCalculator(config_path=PROJECT_CONFIG_PATH,
                                           classifier_names=CLASSIFIER_NAMES,
                                           sigma=s,
                                           gamma=g,hierarchy=h,
                                           hierarchical_search=hs,
                                           input_dir=INPUT_DIR,
                                           output_dir=save_dir)
    kleinberg_runner.run()
# Out:
# Running parameters (1/72): sigma = 1.5, gamma = 0.1, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128085957.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5973s) 	complete
# Running parameters (2/72): sigma = 1.5, gamma = 0.1, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128085957.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4975s) 	complete
# Running parameters (3/72): sigma = 1.5, gamma = 0.1, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128085958.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5382s) 	complete
# Running parameters (4/72): sigma = 1.5, gamma = 0.1, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128085958.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5175s) 	complete
# Running parameters (5/72): sigma = 1.5, gamma = 0.1, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128085959.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5753s) 	complete
# Running parameters (6/72): sigma = 1.5, gamma = 0.1, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090000.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4988s) 	complete
# Running parameters (7/72): sigma = 1.5, gamma = 0.2, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090000.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5192s) 	complete
# Running parameters (8/72): sigma = 1.5, gamma = 0.2, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090001.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4911s) 	complete
# Running parameters (9/72): sigma = 1.5, gamma = 0.2, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090001.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.519s) 	complete
# Running parameters (10/72): sigma = 1.5, gamma = 0.2, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090002.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.482s) 	complete
# Running parameters (11/72): sigma = 1.5, gamma = 0.2, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090002.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5172s) 	complete
# Running parameters (12/72): sigma = 1.5, gamma = 0.2, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090003.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4828s) 	complete
# Running parameters (13/72): sigma = 1.5, gamma = 0.3, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090003.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5232s) 	complete
# Running parameters (14/72): sigma = 1.5, gamma = 0.3, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090004.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4884s) 	complete
# Running parameters (15/72): sigma = 1.5, gamma = 0.3, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090004.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5245s) 	complete
# Running parameters (16/72): sigma = 1.5, gamma = 0.3, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090005.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4943s) 	complete
# Running parameters (17/72): sigma = 1.5, gamma = 0.3, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090005.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5241s) 	complete
# Running parameters (18/72): sigma = 1.5, gamma = 0.3, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090006.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5248s) 	complete
# Running parameters (19/72): sigma = 1.5, gamma = 0.5, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090006.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5532s) 	complete
# Running parameters (20/72): sigma = 1.5, gamma = 0.5, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090007.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4938s) 	complete
# Running parameters (21/72): sigma = 1.5, gamma = 0.5, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090007.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5311s) 	complete
# Running parameters (22/72): sigma = 1.5, gamma = 0.5, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090008.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5124s) 	complete
# Running parameters (23/72): sigma = 1.5, gamma = 0.5, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090008.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5465s) 	complete
# Running parameters (24/72): sigma = 1.5, gamma = 0.5, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090009.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.5266s) 	complete
# Running parameters (25/72): sigma = 2.0, gamma = 0.1, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090009.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4566s) 	complete
# Running parameters (26/72): sigma = 2.0, gamma = 0.1, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090010.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.402s) 	complete
# Running parameters (27/72): sigma = 2.0, gamma = 0.1, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090010.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4734s) 	complete
# Running parameters (28/72): sigma = 2.0, gamma = 0.1, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090011.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4077s) 	complete
# Running parameters (29/72): sigma = 2.0, gamma = 0.1, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090011.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4425s) 	complete
# Running parameters (30/72): sigma = 2.0, gamma = 0.1, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090012.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4347s) 	complete
# Running parameters (31/72): sigma = 2.0, gamma = 0.2, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090012.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4871s) 	complete
# Running parameters (32/72): sigma = 2.0, gamma = 0.2, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090012.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4355s) 	complete
# Running parameters (33/72): sigma = 2.0, gamma = 0.2, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090013.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4641s) 	complete
# Running parameters (34/72): sigma = 2.0, gamma = 0.2, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090013.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4066s) 	complete
# Running parameters (35/72): sigma = 2.0, gamma = 0.2, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090014.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.438s) 	complete
# Running parameters (36/72): sigma = 2.0, gamma = 0.2, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090014.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4008s) 	complete
# Running parameters (37/72): sigma = 2.0, gamma = 0.3, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090015.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.43s) 	complete
# Running parameters (38/72): sigma = 2.0, gamma = 0.3, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090015.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3822s) 	complete
# Running parameters (39/72): sigma = 2.0, gamma = 0.3, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090015.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4267s) 	complete
# Running parameters (40/72): sigma = 2.0, gamma = 0.3, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090016.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3797s) 	complete
# Running parameters (41/72): sigma = 2.0, gamma = 0.3, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090016.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4416s) 	complete
# Running parameters (42/72): sigma = 2.0, gamma = 0.3, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090017.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4293s) 	complete
# Running parameters (43/72): sigma = 2.0, gamma = 0.5, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090017.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4182s) 	complete
# Running parameters (44/72): sigma = 2.0, gamma = 0.5, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090018.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4212s) 	complete
# Running parameters (45/72): sigma = 2.0, gamma = 0.5, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090018.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4257s) 	complete
# Running parameters (46/72): sigma = 2.0, gamma = 0.5, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090018.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3876s) 	complete
# Running parameters (47/72): sigma = 2.0, gamma = 0.5, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090019.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4394s) 	complete
# Running parameters (48/72): sigma = 2.0, gamma = 0.5, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090019.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4056s) 	complete
# Running parameters (49/72): sigma = 3.0, gamma = 0.1, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090020.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3851s) 	complete
# Running parameters (50/72): sigma = 3.0, gamma = 0.1, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090020.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3368s) 	complete
# Running parameters (51/72): sigma = 3.0, gamma = 0.1, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090020.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3959s) 	complete
# Running parameters (52/72): sigma = 3.0, gamma = 0.1, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090021.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3313s) 	complete
# Running parameters (53/72): sigma = 3.0, gamma = 0.1, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090021.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3939s) 	complete
# Running parameters (54/72): sigma = 3.0, gamma = 0.1, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090021.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3373s) 	complete
# Running parameters (55/72): sigma = 3.0, gamma = 0.2, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090022.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3981s) 	complete
# Running parameters (56/72): sigma = 3.0, gamma = 0.2, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090022.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3372s) 	complete
# Running parameters (57/72): sigma = 3.0, gamma = 0.2, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090023.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4394s) 	complete
# Running parameters (58/72): sigma = 3.0, gamma = 0.2, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090023.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3369s) 	complete
# Running parameters (59/72): sigma = 3.0, gamma = 0.2, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090023.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3916s) 	complete
# Running parameters (60/72): sigma = 3.0, gamma = 0.2, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090024.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3312s) 	complete
# Running parameters (61/72): sigma = 3.0, gamma = 0.3, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090024.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3908s) 	complete
# Running parameters (62/72): sigma = 3.0, gamma = 0.3, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090024.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3502s) 	complete
# Running parameters (63/72): sigma = 3.0, gamma = 0.3, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090025.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4036s) 	complete
# Running parameters (64/72): sigma = 3.0, gamma = 0.3, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090025.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3386s) 	complete
# Running parameters (65/72): sigma = 3.0, gamma = 0.3, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090026.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3884s) 	complete
# Running parameters (66/72): sigma = 3.0, gamma = 0.3, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090026.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3404s) 	complete
# Running parameters (67/72): sigma = 3.0, gamma = 0.5, hierarchy = 1, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090026.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4134s) 	complete
# Running parameters (68/72): sigma = 3.0, gamma = 0.5, hierarchy = 1, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090027.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.368s) 	complete
# Running parameters (69/72): sigma = 3.0, gamma = 0.5, hierarchy = 2, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090027.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3797s) 	complete
# Running parameters (70/72): sigma = 3.0, gamma = 0.5, hierarchy = 2, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090027.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3414s) 	complete
# Running parameters (71/72): sigma = 3.0, gamma = 0.5, hierarchy = 3, hierarchy search = True
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# Applying hierarchical search...
# Applying hierarchical search...
# Applying hierarchical search...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090028.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.4302s) 	complete
# Running parameters (72/72): sigma = 3.0, gamma = 0.5, hierarchy = 3, hierarchy search = False
# Processing Kleinberg burst detection for 1 file(s)...
# Kleinberg analysis video Together_1. Video 1/1...
# SIMBA COMPLETE: Kleinberg analysis complete. See /Users/simon/Desktop/envs/troubleshooting/two_black_animals_14bp/project_folder/logs/Kleinberg_detailed_log_20240128090028.csv for details of detected bouts of all classifiers in all hierarchies (elapsed time: 0.3352s) 	complete
